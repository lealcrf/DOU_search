# %%
# %load_ext autoreload
# %autoreload 2

from search import Search
from repository import PublicacoesDB
from datetime import date
from IPython.core.display import display, HTML
import warnings
import pandas as pd
import os

warnings.filterwarnings("ignore")

# %%
with PublicacoesDB() as db:
    df = db.query("SELECT * FROM publicacoes")
    
    
    
    # if os.path.exists("files/publicacoes.csv"):
    #     os.remove("files/publicacoes.csv")
    
    # df.to_csv("files/publicacoes.csv", index=False)
    # df = pd.read_csv("files/publicacoes.csv")

# %%
s = Search(
    df,
    date(2021, 11, 29),
    # is_csv=True,
)

# %%
x = [
    "Banco Central do Brasil",
    "Conselho de Controle de Atividades Financeiras",
    "Grupo de Ação Financeira contra a Lavagem de Dinheiro e o Financiamento do Terrorismo",
    "Comitê de Regulação e Fiscalização dos Mercados Financeiro, de Capitais, de Seguros, de Previdência e Capitalização Proteção de Dados Pessoais",
    "Comitê de Estabilidade Financeira",
    "Comitê Nacional de Educação Financeira",
    "Proteção de dados pessoais",
    "Sistema financeiro",
    "Educação financeira",
    "Imposto sobre Operações Financeiras",
]

# %%
# from utils import ColumnSearch

# d1 = s.keyword_search(
#     searches=[
#         ColumnSearch(
#             [s.df.tipo_normativo],
#             # [s.df.titulo],
#             [
#                 # "^Lei",
#                 "Medida Provisória",
#             ],
#         ),
#         # ColumnSearch(
#         #     [s.df.escopo],
#         #     ["Ministério da Economia"],
#         # ),
#     ]
# ).sort_values("data", ascending=False)


d1 = s.gerar_sumula()

print(len(d1))
d1.where(d1.titulo.str.contains("^(?!.*bar).*$"))
# Out:
# 14
#               id secao tipo_normativo        data  \
# 209105       NaN   NaN            NaN         NaN
# 209106       NaN   NaN            NaN         NaN
# 209107       NaN   NaN            NaN         NaN
# 209108       NaN   NaN            NaN         NaN
# 209109       NaN   NaN            NaN         NaN
# 210462       NaN   NaN            NaN         NaN
# 210545       NaN   NaN            NaN         NaN
# 210557       NaN   NaN            NaN         NaN
# 211543  22948878   DO2       Portaria  2021-11-29
# 210461       NaN   NaN            NaN         NaN
# 210543       NaN   NaN            NaN         NaN
# 210544       NaN   NaN            NaN         NaN
# 211605  22949192   DO1          Pauta  2021-11-29
# 211811  22950234   DO1    Retificação  2021-11-29
#
#                                                    escopo  \
# 209105                                                NaN
# 209106                                                NaN
# 209107                                                NaN
# 209108                                                NaN
# 209109                                                NaN
# 210462                                                NaN
# 210545                                                NaN
# 210557                                                NaN
# 211543     Ministério da Economia/Banco Central do Brasil
# 210461                                                NaN
# 210543                                                NaN
# 210544                                                NaN
# 211605  Ministério da Economia/Banco Central do Brasil...
# 211811  Ministério da Economia/Banco Central do Brasil...
#
#                                                 titulo ementa  \
# 209105                                             NaN    NaN
# 209106                                             NaN    NaN
# 209107                                             NaN    NaN
# 209108                                             NaN    NaN
# 209109                                             NaN    NaN
# 210462                                             NaN    NaN
# 210545                                             NaN    NaN
# 210557                                             NaN    NaN
# 211543  PORTARIA Nº 112.052, DE 26 DE NOVEMBRO DE 2021   None
# 210461                                             NaN    NaN
# 210543                                             NaN    NaN
# 210544                                             NaN    NaN
# 211605                            PAUTA DE JULGAMENTOS   None
# 211811                                     RETIFICAÇÃO   None
#
#                                                  conteudo  \
# 209105                                                NaN
# 209106                                                NaN
# 209107                                                NaN
# 209108                                                NaN
# 209109                                                NaN
# 210462                                                NaN
# 210545                                                NaN
# 210557                                                NaN
# 211543  <p class="identifica">PORTARIA Nº 112.052, DE ...
# 210461                                                NaN
# 210543                                                NaN
# 210544                                                NaN
# 211605  <p class="identifica">PAUTA DE JULGAMENTOS</p>...
# 211811  <p></p><p class="identifica">RETIFICAÇÃO</p><p...
#
#                              assinatura  \
# 209105                              NaN
# 209106                              NaN
# 209107                              NaN
# 209108                              NaN
# 209109                              NaN
# 210462                              NaN
# 210545                              NaN
# 210557                              NaN
# 211543  ROBERTO DE OLIVEIRA CAMPOS NETO
# 210461                              NaN
# 210543                              NaN
# 210544                              NaN
# 211605                     RICARDO LIÁO
# 211811                             None
#
#                                                    motivo
# 209105                                                NaN
# 209106                                                NaN
# 209107                                                NaN
# 209108                                                NaN
# 209109                                                NaN
# 210462                                                NaN
# 210545                                                NaN
# 210557                                                NaN
# 211543  Assinatura de um diretor ou pelo presidente do BC
# 210461                                                NaN
# 210543                                                NaN
# 210544                                                NaN
# 211605  Publicação do BC no DO1 que não é intrução nor...
# 211811  Publicação do BC no DO1 que não é intrução nor...

# %%
display(HTML(d1.conteudo.iloc[0]))
# Out:
# <p class="identifica">PAUTA DE JULGAMENTOS</p><p>Processos incluídos na pauta da Sessão de Julgamento do Plenário do Conselho de Controle de Atividades Financeiras (Coaf) marcada para realizar-se em 8 de dezembro de 2021, por videoconferência, a partir das 9h30 (nove horas e trinta minutos), facultada às partes interessadas, bem como a seus representantes e procuradores, na forma em que foram intimados, a participação remota ou mediante comparecimento à sede do Coaf, situada no Setor de Clubes Esportivos Sul (SCES), Trecho 2, Conjunto 31, Lotes 1A/1B, 2º andar do Edifício Universidade Banco Central (UniBC) - CEP 70200-002 - Brasília/DF:</p><p>1) Processo Administrativo Sancionador nº 11893.100399/2018-74</p><p>Escuderia Comércio de Veículos Ltda., CNPJ 24.446.699/0001-86; e</p><p>Rosela Longo Siropulos Barbosa, CPF 126.440.828-54.</p><p>Relator: Cezar Ermílio Garcia de Vasconcellos</p><p>Procurador: Abrão Jorge Miguel Neto - OAB/SP nº 172.355</p><p>2) Processo Administrativo Sancionador nº 11893.100400/2018-61</p